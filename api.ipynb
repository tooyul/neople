# %%
# 필요한 라이브러리 로드
from dotenv import load_dotenv
import os
import requests

# %%
# .env 파일 로드
load_dotenv()

# 환경 변수에서 API 키 가져오기
df_api_key = os.getenv('API_KEY')
youtube_api_key = os.getenv('YOUTUBE_API_KEY')

# %%
# API URL
df_url = 'https://api.neople.co.kr'

# %%
df_api_endpoints = {
    "서버 정보": "/df/servers",
    "캐릭터 검색": "/df/servers/{server}/characters",
    "캐릭터 기본 정보 조회": "/df/servers/{serverId}/characters/{characterId}",
    "캐릭터 타임라인 정보 조회": "/df/servers/{serverId}/characters/{characterId}/timeline",
    "캐릭터 능력치 정보 조회": "/df/servers/{serverId}/characters/{characterId}/status",
    "캐릭터 장착 장비 조회": "/df/servers/{serverId}/characters/{characterId}/equip/equipment",
    "캐릭터 장착 아바타 조회": "/df/servers/{serverId}/characters/{characterId}/equip/avatar",
    "캐릭터 장착 크리쳐 조회": "/df/servers/{serverId}/characters/{characterId}/equip/creature",
    "캐릭터 장착 휘장 조회": "/df/servers/{serverId}/characters/{characterId}/equip/flag",
    "캐릭터 장착 탈리스만 조회": "/df/servers/{serverId}/characters/{characterId}/equip/talisman",
    "캐릭터 장비 특성 조회": "/df/servers/{serverId}/characters/{characterId}/equip/equipment-trait",
    "캐릭터 스킬 스타일 조회": "/df/servers/{serverId}/characters/{characterId}/skill/style",
    "캐릭터 버프 스킬 강화 장착 장비": "/df/servers/{serverId}/characters/{characterId}/skill/buff/equip/equipment",
    "캐릭터 버프 스킬 강화 장착 아바타": "/df/servers/{serverId}/characters/{characterId}/skill/buff/equip/avatar",
    "캐릭터 버프 스킬 강화 장착 크리처": "/df/servers/{serverId}/characters/{characterId}/skill/buff/equip/creature",
    "캐릭터 명성 검색": "/df/servers/{serverId}/characters-fame",
    "경매장 등록 아이템 검색": "/df/auction",
    "경매장 등록 아이템 조회": "/df/auction/{auctionNo}",
    "경매장 시세 검색": "/df/auction-sold",
    "아바타 마켓 상품 검색": "/df/avatar-market/sale",
    "아바타 마켓 상품 조회": "/df/avatar-market/sale/{goodsNo}",
    "아바타 마켓 상품 시세 검색": "/df/avatar-market/sold",
    "아바타 마켓 상품 시세 조회": "/df/avatar-market/sold/{goodsNo}",
    "아바타 마켓 해시태그 조회": "/df/avatar-market/hashtag",
    "아이템 검색": "/df/items",
    "아이템 상세 정보 조회": "/df/items/{itemId}",
    "아이템 상점 판매 정보 조회": "/df/items/{itemId}/shop",
    "다중 아이템 상세 정보 조회": "/df/multi/items",
    "아이템 해시태그": "/df/item-hashtag",
    "세트 아이템 검색": "/df/setitems",
    "세트 아이템 상세 정보 조회": "/df/setitems/{setItemId}",
    "다중 세트 아이템 상세 정보 조회": "/df/multi/setitems",
    "장비 조합 세트 아이템 활성화 정보 조회": "/df/custom/equipment/setitems",
    "직업 정보": "/df/jobs",
    "직업별 스킬 리스트": "/df/skills/{jobId}",
    "직업별 스킬 상세 정보 조회": "/df/skills/{jobId}/{skillId}"
}

# %%
server_ids =  {'안톤': 'anton', '바칼': 'bakal', '카인': 'cain', '카시야스': 'casillas', '디레지에': 'diregie', '힐더': 'hilder', '프레이': 'prey', '시로코': 'siroco'}

# %%
import json
def prettier_print(data):
    print(json.dumps(data.json(), indent=4, ensure_ascii=False))

# %%
# params = {'apikey' : df_api_key}
params = {'apikey' : df_api_key, 'characterName': '마지막겨울밤'}
res = requests.get(df_url+df_api_endpoints['캐릭터 검색'].format(server=server_ids['힐더']), params=params)

prettier_print(res)
# Out:
# {
#     "rows": [
#         {
#             "serverId": "hilder",
#             "characterId": "f4d38774dc652d0e58991b93cc732fad",
#             "characterName": "마지막겨울밤",
#             "level": 110,
#             "jobId": "41f1cdc2ff58bb5fdc287be0db2a8df3",
#             "jobGrowId": "37495b941da3b1661bc900e68ef3b2c6",
#             "jobName": "귀검사(남)",
#             "jobGrowName": "眞 웨펀마스터",
#             "fame": 62686
#         }
#     ]
# }

# %%
# Test 셀
import urllib.parse
avatar_name = '코트'
encoded_name = urllib.parse.quote(avatar_name)
test = requests.get(f'https://api.neople.co.kr/df/avatar-market/sale?hashtag={encoded_name}&wordType=full&apikey=5xeX0izDvOqnVrpl5WbgAJfvwgIFt4Tn')
prettier_print(test)
# Out:
# {
#     "rows": []
# }

# %%
import requests
import json

# 유튜브 데이터 API 키
api_key = 'AIzaSyAU0kEsB4uKYg2zX3_FFiynhYUgUeCNSaw'

# 검색할 키워드
search_query = '던파 가이드'

# API 요청 URL
url = f'https://www.googleapis.com/youtube/v3/search?part=snippet&q={search_query}&type=video&maxResults=50&key={api_key}'

# API 요청 보내기
response = requests.get(url)
data = response.json()

# 동영상 정보 출력
for item in data['items']:
    title = item['snippet']['title']
    channel = item['snippet']['channelTitle']
    publish_date = item['snippet']['publishedAt']
    video_id = item['id']['videoId']
    video_url = f'https://www.youtube.com/watch?v={video_id}'
    
    print(f'제목: {title}')
    print(f'채널명: {channel}')
    print(f'업로드 날짜: {publish_date}')
    print(f'URL: {video_url}')
    print('----------------------------------')
# Out:
# 제목: 안보면 쌉손해! 던파 뉴비를 위한 꿀팁 10가지
# 채널명: 장지
# 업로드 날짜: 2024-03-24T07:22:29Z
# URL: https://www.youtube.com/watch?v=AoBdO3JYnXs
# ----------------------------------
# 제목: 지금 던파 시작 하지마세요
# 채널명: 카왑TV
# 업로드 날짜: 2024-04-27T09:51:26Z
# URL: https://www.youtube.com/watch?v=jd-USRBIp4U
# ----------------------------------
# 제목: [던파] 초보를 위해 만들어진 세트장비 가이드
# 채널명: 쌀먹충
# 업로드 날짜: 2024-05-06T15:23:02Z
# URL: https://www.youtube.com/watch?v=RkqiMQrCk60
# ----------------------------------
# 제목: [던파] 신규 복귀를 위한 초간단 직업 추천 가이드
# 채널명: 휘호
# 업로드 날짜: 2024-04-24T04:10:00Z
# URL: https://www.youtube.com/watch?v=Ek3xoGXNgcc
# ----------------------------------
# 제목: 던파] 뉴비 복귀 필독! 장비 파밍 설명회 [고정,기억,기록/흔적]
# 채널명: 옥선생
# 업로드 날짜: 2024-05-24T00:00:16Z
# URL: https://www.youtube.com/watch?v=OCTLwZwf16M
# ----------------------------------
# 제목: 【던파】 신규, 복귀 유저가 꼭 봐야될 2023 &#39;선계 파밍 가이드&#39; (파밍 루트, 장비 업그레이드, 옵션 성장, 특성, 상급 던전, 미스트 기어, 미광의 부유석)
# 채널명: 장지
# 업로드 날짜: 2023-09-13T13:22:33Z
# ...

# %%
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {
#     "kind": "youtube#searchListResponse",
#     "etag": "wx_hiT1kS_B5u9IT1PMcuBSzwJI",
#     "nextPageToken": "CDIQAA",
#     "regionCode": "KR",
#     "pageInfo": {
#         "totalResults": 579209,
#         "resultsPerPage": 50
#     },
#     "items": [
#         {
#             "kind": "youtube#searchResult",
#             "etag": "_86H_DNKFi1g-Vv9FXzQCFdWeFo",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "VctQg3K7qF4"
#             },
#             "snippet": {
#                 "publishedAt": "2024-05-22T03:09:05Z",
#                 "channelId": "UChHxLcNi7e0zu-e33HM6v6A",
#                 "title": "던붕이들아 나왔어~ ^_^  ㅣ던전앤파이터",
#                 "description": "배돈 #던전앤파이터 생방송 https://chzzk.naver.com/554e99695decc451d57788b1fd5d5c07 이메일 songiya7@naver.com 팬카페 ...",
#                 "thumbnails": {
#                     "default": {
#                         "url": "https://i.ytimg.com/vi/VctQg3K7qF4/default.jpg",
# ...
